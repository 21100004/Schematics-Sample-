# %%
from IPython.display import Image
from IPython.display import display
display(Image(filename = "images/images/1.PNG", width = "700", height = "700", embed = True))

# %%
from IPython.display import Image
from IPython.display import display
display(Image(filename = "images/images/2.PNG", width = "700", height = "700", embed = True))

# %%
from IPython.display import Image
from IPython.display import display
display(Image(filename = "images/images/3.PNG", width = "700", height = "700", embed = True))

# %%
from IPython.display import Image
from IPython.display import display
display(Image(filename = "images/images/4.PNG", width = "700", height = "700", embed = True))
